# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Exercise 1.1: PCA: 2-dimensional Toy Data

# %% [markdown]
# We firstly load 2d data-set.

# %%
data = np.genfromtxt('pca-data-2d.dat', dtype=None, delimiter='')

# %% [markdown]
# We center the data and plot a scatter plot

# %%
centered_data = data - np.mean(data, axis=0)
plt.scatter(centered_data[:,0], centered_data[:,1]);
plt.show();

# %% [markdown]
# We calculate the covarianceMatrix, eigenvalues and eigenvectors.
# Then we project on the two eigenvectors. We can clearly see that these are the vectors with the largest variance.

# %%
cov = np.cov(centered_data.T)
ev , eig = np.linalg.eig(cov)
proj = np.dot(centered_data,eig.T)
plt.scatter(proj[:,1], proj[:,0]);
plt.show();

# %% [markdown]
# (i) We only use the first PCA to reconstruct the data.

# %%
reconstructed = np.dot(np.expand_dims(proj[:,1], axis=1), np.expand_dims(eig.T[0].T, axis=0)) 
plt.scatter(reconstructed[:,1],reconstructed[:,0]);
plt.show();

# %%
reconstructed = np.dot(np.expand_dims(proj[:,0], axis=1), np.expand_dims(eig.T[1].T, axis=0)) 
plt.scatter(reconstructed[:,1],reconstructed[:,0]);
plt.show();

# %% [markdown]
# # Exercise 1.2: PCA: 3-dimensional Toy Data

# %% [markdown]
# We firstly load 3d data-set.

# %%
data = np.genfromtxt('pca-data-3d.dat', dtype=None, delimiter=',')
centered_data = data - np.mean(data,axis=0)

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(centered_data[:,0], centered_data[:,1], centered_data[:,2], c='r', marker='o')
plt.show()

# %%
cov = np.cov(centered_data.T)

# %%
ev, eig = np.linalg.eig(cov)
data_proj = np.dot(centered_data, eig.T)
# Out:
# 4.08137783622

# %%
plt.scatter(data_proj[:,0], data_proj[:,1]);
plt.show();

plt.scatter(data_proj[:,0], data_proj[:,2]);
plt.show();

plt.scatter(data_proj[:,1], data_proj[:,2]);
plt.show();
# Out:
# 4.08137783622

# %%
reconstructed_first_pc = np.dot(np.expand_dims(data_proj[:,2], axis=1), np.expand_dims(eig.T[2].T, axis=0)) 

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(reconstructed_first_pca[:,0], reconstructed_first_pc[:,1], reconstructed_first_pc[:,2], c='r', marker='o')
plt.show()

# %%
reconstructed_two_pc = np.dot(data_proj[:,0:2], eig.T[0:2]) 
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(reconstructed_two_pc[:,0], reconstructed_two_pc[:,1], reconstructed_two_pc[:,2], c='r', marker='o')
plt.show()

# %%
reconstructed_three_pc = np.dot(data_proj[:,0:3], eig.T[0:3]) 
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(reconstructed_three_pc[:,0], reconstructed_three_pc[:,1], reconstructed_three_pc[:,2], c='r', marker='o')
plt.show()
